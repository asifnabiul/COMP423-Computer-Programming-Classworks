# %% [markdown]
# # Week 2: Loops & Patterns — Practice Problems (Beginner Friendly)
#
# This notebook contains **6 short problems** to practice:
# - `for` and `while` loops
# - printing tables and simple star patterns
# - basic iteration and accumulation
#
# Each problem has a **Markdown description** and an **empty code cell** for your solution.

# %% [markdown]
# ## 🔹 Problem 1 — Times Table (for loop)
#
# **Task:** Ask the user for an integer `n` and print its multiplication table from **1 to 10** in the format:
# ```
# n x 1 = ...
# n x 2 = ...
# ...
# n x 10 = ...
# ```
# **Hint:** Use a `for` loop over `range(1, 11)` and f-strings.

# %%
# Write your code here for Problem 1


n = int(input("Enter a positive integer"))

for i in range(1, 11):
    print(f"{n} x {i} = {n * i}")
# Out:
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %% [markdown]
# ## 🔹 Problem 2 — Star Pattern (for loop)
#
# **Task:** Ask the user for an integer `n` and print a **right-angled triangle** of stars like this (for `n = 5`):
# ```
# *
# **
# ***
# ****
# *****
# ```
# **Hint:** You can print `'*' * i` inside a loop.
# **Bonus:** After that, print the **inverted triangle** too.

# %%
# Write your code here for Problem 2

# %% [markdown]
# ## 🔹 Problem 3 — Sum 1..n (while loop)
#
# **Task:** Ask the user for an integer `n` and compute the **sum of numbers from 1 to n** **using a `while` loop** (don't use `sum()` yet).
# Print the total at the end.
#
# **Example:** for `n = 5`, the sum is `1 + 2 + 3 + 4 + 5 = 15`.

# %%
# Write your code here for Problem 3

n = int(input("Enter a positive integer: "))


sum = 0

i = 0
while i <= n:
    sum += i
    i += 1
    
print(f"The sum of first {n} natural numbers is: {sum}")
# Out:
# The sum of first 10 natural numbers is: 55

# %% [markdown]
# ## 🔹 Problem 4 — Average of Marks (for loop)
#
# **Task:** You are given a list of marks (out of 100), e.g.:
# ```python
# marks = [72, 88, 91, 64, 79]
# ```
# 1. Compute the **average mark** using a `for` loop to accumulate the total (avoid `sum()` for practice).
# 2. Print the average as a **float**.
# 3. (Optional) Round to **2 decimal places** when printing.
#
# **Hint:** Keep a running total, then divide by `len(marks)`.

# %%
# Write your code here for Problem 4
# Feel free to change the list to test different values

marks = [72, 88, 91, 64, 79]

total = 0 

for i in marks:
    total+= i  #similar to total = total+i

average =  total / len(marks)

print(f"The average marks is: {average: .2f}")
# Out:
# The average marks is:  78.80

# %% [markdown]
# ## 🔹 Problem 5 — Mini FizzBuzz (for + conditionals)
#
# **Task:** Print the numbers from **1 to 20**.
# - For multiples of **3**, print `"Fizz"` instead of the number.
# - For multiples of **5**, print `"Buzz"`.
# - For numbers that are multiples of **both 3 and 5**, print `"FizzBuzz"`.
#
# **Hint:** Use `%` (modulo) to test divisibility.

# %%
# Write your code here for Problem 5

# %% [markdown]
# ## 🔹 Problem 6 — Count Vowels (for over string)
#
# **Task:** Ask the user to enter a **word or sentence**. Count how many **vowels** it contains (`a, e, i, o, u`) and print the total.
# Ignore case (treat `A` the same as `a`).
#
# **Hint:** Convert the input to lowercase with `.lower()` and loop through the characters.

# %%
# Write your code here for Problem 6

text = input ("Enter a word or a line of text: ").lower()

vowels = "aeiou"

count = 0 

for char in text:
    if char in vowels:
        count = count + 1

print(f"The number of vowels in the given text is: {count}")
# Out:
# The number of vowels in the given text is: 5
